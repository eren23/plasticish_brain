# %%
# !git clone www.github.com/eren23/plasticish_brain.git

# %%
# %cd plasticish_brain/
# Out:
# /content/plasticish_brain

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/plasticish_brain
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for plasticish
# ...

# %%
# !python examples/train_cifar10.py
# Out:
# Using device: cuda
# Architecture: 512 → 8192 (sparse) → 10
# Sparsity: 32/8192 = 0.39%
#
# Loading CIFAR-10 dataset...
# 100% 170M/170M [00:13<00:00, 12.3MB/s]
# Animals: 30000 samples
# Vehicles: 20000 samples
# Memory Test: 500 samples
#
# Initializing Triarchic Brain...
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 171MB/s]
# Eyes: ResNet18 (frozen)
# Brain: 4440064 parameters
#   - Projection: 4194304 (dynamic)
#   - Core Weights: 81920 (slow + protected)
#   - Context Weights: 81920 (fast + decaying)
#   - Importance Matrix: 81920 (consolidation)
#
# Starting continual learning simulation...
#
# ...
# TRIARCHIC BRAIN: CONTINUAL LEARNING SIMULATION
# ...
#
# ...
# PHASE 1: ANIMALS
# Duration: 1500 steps
# Goal: Build core knowledge via neurogenesis and consolidation
# ...
#
# Step    0 |    Animals | Task: 0.00% | Memory: 53.00% | Active Neurons: 64
# ...
